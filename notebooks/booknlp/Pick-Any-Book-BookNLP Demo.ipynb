# %% [markdown]
# # BookNLP Demo — Get Characters, People, Places, Quotations, Etc. for Any Book

# %% [markdown]
# By [Melanie Walsh](https://melaniewalsh.org/), based on a notebook by [David Bamman](https://people.ischool.berkeley.edu/~dbamman/)
#
# [BookNLP](https://github.com/booknlp/booknlp) is a natural language processing tool developed by David Bamman. This tool can computationally identify characters, people, places, quotations, events, and  a lot more for book-length documents in English (support for other languages coming soon!). Most NLP tools do not work well on book-length documents, which makes BookNLP extremely useful.
#
# This Colab notebook, which is [based on a notebook](https://github.com/booknlp/booknlp/blob/main/examples/Read%20character%20file.ipynb) created by David Bamman, demonstrates how BookNLP works with a single book. The default book for this notebook is Virginia Woolf's *Mrs. Dalloway* (1925). However, you can substitue another URL in the "Pick Your Book" section to try BookNLP out on another book. BookNLP will take a few minutes to process a text, depending on how long it is.
#
# # 🚨 Before You Begin 🚨
#
# First, you need to sign into a Google account to use this notebook.
#
# Second, BookNLP will work best if you switch to using a GPU, or Graphical Processing Unit, for this notebook. To use a GPU in Google Colab, go to the menu at the top of the screen and select:
#
# `Runtime > Change runtime type > Hardware accelerator > GPU (Then slick "Save")`
#
# To run all the code in this notebook, you can select:
#
# `Runtime > Run all`
#
# If you want to save your own changes to this notebook, you'll need to save a copy.

# %% [markdown]
# # Pick Your Book

# %% [markdown]
# The default book for this notebook is Virginia Woolf's *Mrs. Dalloway*: https://gutenberg.net.au/ebooks02/0200991.txt. But you can find a .txt URL from [Project Gutenberg](https://www.gutenberg.org/ebooks/search/?sort_order=downloads) or GitHub or anywhere else and plug it in below:

# %%
# !wget "https://gutenberg.net.au/ebooks02/0200991.txt" -O my_book.txt
# Out:
# --2021-11-22 21:48:01--  https://gutenberg.net.au/ebooks02/0200991.txt
# Resolving gutenberg.net.au (gutenberg.net.au)... 43.229.63.241
# Connecting to gutenberg.net.au (gutenberg.net.au)|43.229.63.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 370280 (362K) [text/plain]
# Saving to: ‘my_book.txt’
#
# my_book.txt         100%[===================>] 361.60K   449KB/s    in 0.8s
#
# 2021-11-22 21:48:03 (449 KB/s) - ‘my_book.txt’ saved [370280/370280]

# %% [markdown]
# Then click `Runtime > Run All`

# %% [markdown]
# # Install and Import Packages

# %%
# !pip install booknlp
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: booknlp in /usr/local/lib/python3.7/dist-packages (1.0.6)
# Requirement already satisfied: transformers>=4.11.3 in /usr/local/lib/python3.7/dist-packages (from booknlp) (4.12.5)
# Requirement already satisfied: tensorflow>=1.15 in /usr/local/lib/python3.7/dist-packages (from booknlp) (2.7.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from booknlp) (1.10.0+cu111)
# Requirement already satisfied: spacy>=3 in /usr/local/lib/python3.7/dist-packages (from booknlp) (3.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (8.0.13)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.6.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (4.62.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.4.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3->booknlp) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3->booknlp) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.2.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (12.0.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.1.2)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.22.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.42.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.13.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.6.3)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.12.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.37.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=1.15->booknlp) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (2019.12.20)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (0.0.46)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (0.1.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (0.10.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3->booknlp) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3->booknlp) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.11.3->booknlp) (1.1.0)
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 8.2 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.2.0) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.19.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from booknlp.booknlp import BookNLP
import json
from collections import Counter
from pathlib import Path
import pandas as pd
pd.options.display.max_rows = 200
pd.options.display.max_colwidth = 100
# Out:
# using device cuda

# %% [markdown]
# # Set Up BookNLP

# %%
model_params = {
		"pipeline":"entity,quote,supersense,event,coref", 
		"model":"big", 
	}

booknlp= BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# --- startup: 17.561 seconds ---

# %% [markdown]
# # Run BookNLP

# %% [markdown]
# Before we apply BookNLP, let's check to make sure our text file has the right character encoding.
#
# If your text file has a character encoding that is not UTF-8 or ISO-8859-1, then you will need to uncomment the last two lines in the code cell below and manually enter the character encoding of the file before transforming it into a UTF-8 file.

# %%
# Check to see if text file opens with UTF-8 encoding
try:
    open("my_book.txt", encoding='utf-8').read()
except UnicodeDecodeError:
    try:
      # Check to see if file opens with ISO-8859-1 encoding and, if so, rewrite the file as UTF-8
      text = open("my_book.txt", encoding='ISO-8859-1').read()
      open('my_book.txt', mode='w', encoding='utf-8').write(text)
    except:
      print("Character encoding error: You need to uncomment the lines above and specify the character encoding for this text file")
 
# Open the file with the current encoding
#text = open("my_book.txt", encoding='Your Character Encoding Here').read()
# Rewrite the file as a UTF-8 file
#open('my_book.txt', mode='w', encoding='utf-8'.write(text)

# %% [markdown]
# Apply BookNLP

# %%
inputFile = "my_book.txt"
outputDir = "my_book_dir/"
idd="my_book"

booknlp.process(inputFile, outputDir, idd)
# Out:
# --- spacy: 26.765 seconds ---
# --- entities: 80.104 seconds ---
# --- quotes: 0.149 seconds ---
# --- attribution: 5.977 seconds ---
# --- name coref: 0.655 seconds ---
# --- coref: 26.719 seconds ---
# --- TOTAL (excl. startup): 140.780 seconds ---, 78358 words

# %% [markdown]
# # Get Character Data

# %% [markdown]
# Load character data

# %%
character_data = json.load(open("my_book_dir/my_book.book"))

# %% [markdown]
# Make a counter

# %%
def get_counter_from_dependency_list(dependency_list):
    
    counter = Counter()

    for token in dependency_list:
        term = token["w"]
        tokenGlobalIndex=token["i"]
        counter[term] += 1
    return counter

# %% [markdown]
# Loop through character data and pull out information, then transform it into a DataFrame

# %%
df_list = []
for character in character_data["characters"]:
    
    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]
        
        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#                                                Name  ...                                                                                            Modifiers
# 0                                          Clarissa  ...  [(positive, 3), (girl, 2), (cold, 2), (happy, 2), (pause, 1), (suspense, 1), (right, 1), (part, ...
# 1                                             Peter  ...  [(happy, 2), (failure, 2), (man, 2), (sticks, 1), (old, 1), (older, 1), (adventurer, 1), (buccan...
# 2                                       Miss Kilman  ...  [(poor, 3), (able, 1), (dismissal, 1), (creature, 1), (serious, 1), (good, 1), (hungry, 1), (fon...
# 3                                             Sally  ...  [(excited, 1), (reckless, 1), (absurd, 1), (alone, 1), (old, 1), (best, 1), (spiteful, 1), (fran...
# 4                                       Sir William  ...  [(free, 2), (certain, 2), (happy, 1), (young, 1), (ill, 1), (fit, 1), (man, 1), (master, 1), (ri...
# 5                                       Lady Bruton  ...  [(general, 1), (sure, 1), (asleep, 1), (right, 1), (woman, 1), (good, 1), (admirable, 1), (happy...
# 6                                         Elizabeth  ...  [(dark, 1), (child, 1), (charming, 1), (interested, 1), (bored, 1), (delighted, 1), (right, 1), ...
# 7                                              Hugh  ...  [(unselfish, 2), (slow, 2), (intolerable, 1), (impossible, 1), (certain, 1), (specimen, 1), (muc...
# 8                                             Rezia  ...                                                  [(afraid, 1), (sewing, 1), (careful, 1), (tree, 1)]
# 9                                           Richard  ...        [(torpid, 1), (happy, 1), (able, 1), (best, 1), (strict, 1), (prig, 1), (help, 1), (glad, 1)]
# 10                                       Dr. Holmes  ...                                                [(man, 2), (interested, 1), (weak, 1), (porridge, 1)]
# 11                                         Septimus  ...                                                                                          [(sure, 1)]
# 12                                            Evans  ...                                                          [(flowers, 1), (tables, 1), (daughters, 1)]
# 13                                         Lucrezia  ...                                                                                         [(happy, 1)]
# 14                                      Mrs. Filmer  ...                                                                  [(close, 1), (good, 1), (brave, 1)]
# 15                                       Mr. Brewer  ...                                                                                                   []
# 16                                             Lucy  ...                                                                                                   []
# 17                                            Daisy  ...                                                                                           [(old, 1)]
# 18                                   old Miss Parry  ...                                                                              [(alive, 2), (dead, 1)]
# 19                                      Mr. Willett  ...                                                                             [(young, 1), (about, 1)]
# 20                                    Lady Bradshaw  ...                                                                                                   []
# 21                                    Mrs. Dalloway  ...                                                                                                   []
# 22                                            Rezia  ...                                                                                       [(unhappy, 1)]
# 23                                 Millicent Bruton  ...                                                                                         [(proud, 1)]
# 24                                    Mrs. Dempster  ...                                                                                                   []
# 25                                      Aunt Helena  ...                                                                                                   []
# 26                                        Sir Harry  ...                                                                                                   []
# 27                                              God  ...                                                                                    [(accessible, 1)]
# 28                                        Mr. Walsh  ...                                                                                                   []
# 29                                      Shakespeare  ...                                                                                                   []
# 30                                     Mr. Dalloway  ...                                                                         [(glad, 1), (dependable, 1)]
# 31                                     Mrs. Hilbery  ...                                                                                                   []
# 32                                      Mrs. Peters  ...                                                                                         [(woman, 2)]
# 33                                          Wilkins  ...                                                                                                   []
# 34                                           Hutton  ...                                                                                                   []
# 35                                     St. Margaret  ...                                                                    [(right, 1), (ill, 1), (dead, 1)]
# 36                                 Miss Isabel Pole  ...                                                                                                   []
# 37                                       Miss Brush  ...                                                                                                   []
# 38                                     the Morrises  ...                                                                                                   []
# 39                                           Gordon  ...                                                                                                   []
# 40                                           Evelyn  ...                                                                                          [(deal, 1)]
# 41                                         Miss Pym  ...                                                                                                   []
# 42                                      Mrs. Walker  ...                                                                                                   []
# 43                                          Big Ben  ...                                                                                                   []
# 44                                 Edgar J. Watkiss  ...                                                                                                   []
# 45                                       Mr. Bowley  ...                                                                                                   []
# 46                                     Sally Parker  ...                                                                                     [(character, 1)]
# 47                                      Milly Brush  ...                                                                                                   []
# 48                                        Mr. Smith  ...                                                                                           [(man, 1)]
# 49                                    Mr. Whittaker  ...                                                                                                   []
# 50                                     Mr. Fletcher  ...                                                                                         [(proud, 1)]
# 51                                Professor Brierly  ...                                                                                                   []
# 52                                     Mrs. Marsham  ...                                                                                                   []
# 53                                     Doris Kilman  ...                                                                                                   []
# 54                               Elizabeth Dalloway  ...                                                                                                   []
# 55                                       Mr. Morris  ...                                                                                                   []
# 56                                  Lady Bexborough  ...                                                                                                   []
# 57                                   Queen Victoria  ...                                                                                                   []
# 58                                             Papa  ...                                                                                                   []
# 59                                 Joseph Breitkopf  ...                                                                                                   []
# 60                                    the Dalloways  ...                                                                                                   []
# 61                                   Miss Elizabeth  ...                                                                                                   []
# 62                                    Lady Rosseter  ...                                                                                                   []
# 63                                  Sarah Bletchley  ...                                                                                                   []
# 64                                        Mrs. Hugh  ...                                                                                    [(negligible, 1)]
# 65                                            Agnes  ...                                                                                                   []
# 66                                     Lady Lovejoy  ...                                                                                                   []
# 67                                           Heaven  ...                                                                                                   []
# 68                                      Mr. Bentley  ...                                                                                                   []
# 69                                        Mr. Parry  ...                                                                                          [(dead, 1)]
# 70                                     Justin Parry  ...                                                                                                   []
# 71                             dear old Lord Lexham  ...                                                                                                   []
# 72                                   the Whitbreads  ...                                                                                                   []
# 73                                            Edith  ...                                                                                          [(sure, 1)]
# 74                                          Berties  ...                                                                                                   []
# 75                                       Miss Dolby  ...                                                                                       [(happier, 1)]
# 76                                          Bourton  ...                                                                                                   []
# 77                                             June  ...                                                                                                   []
# 78                                         Sir John  ...                                                                                                   []
# 79                                   Willie Titcomb  ...                                                                                                   []
# 80                               Shawled Moll Pratt  ...                                                                                                   []
# 81                                      Mrs. Coates  ...                                                                                                   []
# 82                                  Carrie Dempster  ...                                                                                                   []
# 83                                   Herbert Ainsty  ...                                                                                                   []
# 84                                          Wickham  ...                                                                                                   []
# 85                            little Elise Mitchell  ...                                                                                                   []
# 86                                           Evelyn  ...                                                                                                   []
# 87                                        Cleopatra  ...                                                                                                   []
# 88                                     Mr. Dubonnet  ...                                                                                                   []
# 89                                   Mrs. Parkinson  ...                                                                                                   []
# 90                                            Jenny  ...                                                                                                   []
# 91                                      Mrs. Barnet  ...                                                                                                   []
# 92                                           Milton  ...                                                                                                   []
# 93                                       Nancy Blow  ...                                                                                                   []
# 94                                    the Bradshaws  ...                                                                                                   []
# 95                                     Baron Marbot  ...                                                                                                   []
# 96                                 Marie Antoinette  ...                                                                                                   []
# 97                                           Darwin  ...                                                                                                   []
# 98                                           Beauty  ...                                                                                                   []
# 99                                           Antony  ...                                                                                                   []
# 100                                           Rigby  ...                                                                                                   []
# 101                                  Mrs. Whitbread  ...                                                                                                   []
# 102                                       Armenians  ...                                                                                                   []
# 103                                      Mr. Peters  ...                                                                                                   []
# 104                                    Mrs. Burgess  ...                                                                                                   []
# 105                                  Bartlett pears  ...                                                                                                   []
# 106                                      Miss Alice  ...                                                                                                   []
# 107                                     Lord Gayton  ...                                                                                                   []
# 108                                   Mrs. Foxcroft  ...                                                                                                   []
# 109                                           Lords  ...                                                                                                   []
# 110                                          Wagner  ...                                                                                                   []
# 111                                            Pope  ...                                                                                                   []
# 112                                          Sylvia  ...                                                                                                   []
# 113                                        Mulberry  ...                                                                                                   []
# 114                                   Princess Mary  ...                                                                                                   []
# 115  old King Edward , but was ever so much slimmer  ...                                                                                                   []
# 116                                  Mrs. Bletchley  ...                                                                                                   []
# 117                                           Roses  ...                                                                                                   []
# 118                                  William Morris  ...                                                                                                   []
# 119                                    Ellen Atkins  ...                                                                                                   []
# 120                                         Othello  ...                                                                                                   []
# 121                                          Brahms  ...                                                                                                   []
# 122                                  Messrs. Hooper  ...                                                                                                   []
# 123                                          Huxley  ...                                                                                                   []
# 124                                           Dante  ...                                                                                                   []
# 125                                     The English  ...                                                                                        [(silent, 1)]
# 126                               the Warren Smiths  ...                                                                                                   []
# 127                                         Lowndes  ...                                                                                                   []
# 128                                      Sir Talbot  ...                                                                                                   []
# 129                                         Perkins  ...                                                                                                   []
# 130                                       Albanians  ...                                                                                                   []
# 131                                     the Germans  ...                                                                                      [(villains, 1)]
# 132                       the Rev. Edward Whittaker  ...                                                                                                   []
# 133                            young Charles Morris  ...                                                                                                   []
# 134                                     Miss Elaine  ...                                                                                                   []
# 135                                     Mrs. Morris  ...                                                                                                   []
# 136                                    Miss Lovejoy  ...                                                                                                   []
# 137                                      Ralph Lyon  ...                                                                                                   []
#
# [138 rows x 8 columns]

# %% [markdown]
# # View Character Data

# %% [markdown]
# Let's view the most frequently mentioned characters as well as their referential gender, actions for the which they are the agent and patient, objects they possess, and modifiers.

# %%
df
# Out:
#                                                Name  ...                                                                                            Modifiers
# 0                                          Clarissa  ...  [(positive, 3), (girl, 2), (cold, 2), (happy, 2), (pause, 1), (suspense, 1), (right, 1), (part, ...
# 1                                             Peter  ...  [(happy, 2), (failure, 2), (man, 2), (sticks, 1), (old, 1), (older, 1), (adventurer, 1), (buccan...
# 2                                       Miss Kilman  ...  [(poor, 3), (able, 1), (dismissal, 1), (creature, 1), (serious, 1), (good, 1), (hungry, 1), (fon...
# 3                                             Sally  ...  [(excited, 1), (reckless, 1), (absurd, 1), (alone, 1), (old, 1), (best, 1), (spiteful, 1), (fran...
# 4                                       Sir William  ...  [(free, 2), (certain, 2), (happy, 1), (young, 1), (ill, 1), (fit, 1), (man, 1), (master, 1), (ri...
# 5                                       Lady Bruton  ...  [(general, 1), (sure, 1), (asleep, 1), (right, 1), (woman, 1), (good, 1), (admirable, 1), (happy...
# 6                                         Elizabeth  ...  [(dark, 1), (child, 1), (charming, 1), (interested, 1), (bored, 1), (delighted, 1), (right, 1), ...
# 7                                              Hugh  ...  [(unselfish, 2), (slow, 2), (intolerable, 1), (impossible, 1), (certain, 1), (specimen, 1), (muc...
# 8                                             Rezia  ...                                                  [(afraid, 1), (sewing, 1), (careful, 1), (tree, 1)]
# 9                                           Richard  ...        [(torpid, 1), (happy, 1), (able, 1), (best, 1), (strict, 1), (prig, 1), (help, 1), (glad, 1)]
# 10                                       Dr. Holmes  ...                                                [(man, 2), (interested, 1), (weak, 1), (porridge, 1)]
# 11                                         Septimus  ...                                                                                          [(sure, 1)]
# 12                                            Evans  ...                                                          [(flowers, 1), (tables, 1), (daughters, 1)]
# 13                                         Lucrezia  ...                                                                                         [(happy, 1)]
# 14                                      Mrs. Filmer  ...                                                                  [(close, 1), (good, 1), (brave, 1)]
# 15                                       Mr. Brewer  ...                                                                                                   []
# 16                                             Lucy  ...                                                                                                   []
# 17                                            Daisy  ...                                                                                           [(old, 1)]
# 18                                   old Miss Parry  ...                                                                              [(alive, 2), (dead, 1)]
# 19                                      Mr. Willett  ...                                                                             [(young, 1), (about, 1)]
# 20                                    Lady Bradshaw  ...                                                                                                   []
# 21                                    Mrs. Dalloway  ...                                                                                                   []
# 22                                            Rezia  ...                                                                                       [(unhappy, 1)]
# 23                                 Millicent Bruton  ...                                                                                         [(proud, 1)]
# 24                                    Mrs. Dempster  ...                                                                                                   []
# 25                                      Aunt Helena  ...                                                                                                   []
# 26                                        Sir Harry  ...                                                                                                   []
# 27                                              God  ...                                                                                    [(accessible, 1)]
# 28                                        Mr. Walsh  ...                                                                                                   []
# 29                                      Shakespeare  ...                                                                                                   []
# 30                                     Mr. Dalloway  ...                                                                         [(glad, 1), (dependable, 1)]
# 31                                     Mrs. Hilbery  ...                                                                                                   []
# 32                                      Mrs. Peters  ...                                                                                         [(woman, 2)]
# 33                                          Wilkins  ...                                                                                                   []
# 34                                           Hutton  ...                                                                                                   []
# 35                                     St. Margaret  ...                                                                    [(right, 1), (ill, 1), (dead, 1)]
# 36                                 Miss Isabel Pole  ...                                                                                                   []
# 37                                       Miss Brush  ...                                                                                                   []
# 38                                     the Morrises  ...                                                                                                   []
# 39                                           Gordon  ...                                                                                                   []
# 40                                           Evelyn  ...                                                                                          [(deal, 1)]
# 41                                         Miss Pym  ...                                                                                                   []
# 42                                      Mrs. Walker  ...                                                                                                   []
# 43                                          Big Ben  ...                                                                                                   []
# 44                                 Edgar J. Watkiss  ...                                                                                                   []
# 45                                       Mr. Bowley  ...                                                                                                   []
# 46                                     Sally Parker  ...                                                                                     [(character, 1)]
# 47                                      Milly Brush  ...                                                                                                   []
# 48                                        Mr. Smith  ...                                                                                           [(man, 1)]
# 49                                    Mr. Whittaker  ...                                                                                                   []
# 50                                     Mr. Fletcher  ...                                                                                         [(proud, 1)]
# 51                                Professor Brierly  ...                                                                                                   []
# 52                                     Mrs. Marsham  ...                                                                                                   []
# 53                                     Doris Kilman  ...                                                                                                   []
# 54                               Elizabeth Dalloway  ...                                                                                                   []
# 55                                       Mr. Morris  ...                                                                                                   []
# 56                                  Lady Bexborough  ...                                                                                                   []
# 57                                   Queen Victoria  ...                                                                                                   []
# 58                                             Papa  ...                                                                                                   []
# 59                                 Joseph Breitkopf  ...                                                                                                   []
# 60                                    the Dalloways  ...                                                                                                   []
# 61                                   Miss Elizabeth  ...                                                                                                   []
# 62                                    Lady Rosseter  ...                                                                                                   []
# 63                                  Sarah Bletchley  ...                                                                                                   []
# 64                                        Mrs. Hugh  ...                                                                                    [(negligible, 1)]
# 65                                            Agnes  ...                                                                                                   []
# 66                                     Lady Lovejoy  ...                                                                                                   []
# 67                                           Heaven  ...                                                                                                   []
# 68                                      Mr. Bentley  ...                                                                                                   []
# 69                                        Mr. Parry  ...                                                                                          [(dead, 1)]
# 70                                     Justin Parry  ...                                                                                                   []
# 71                             dear old Lord Lexham  ...                                                                                                   []
# 72                                   the Whitbreads  ...                                                                                                   []
# 73                                            Edith  ...                                                                                          [(sure, 1)]
# 74                                          Berties  ...                                                                                                   []
# 75                                       Miss Dolby  ...                                                                                       [(happier, 1)]
# 76                                          Bourton  ...                                                                                                   []
# 77                                             June  ...                                                                                                   []
# 78                                         Sir John  ...                                                                                                   []
# 79                                   Willie Titcomb  ...                                                                                                   []
# 80                               Shawled Moll Pratt  ...                                                                                                   []
# 81                                      Mrs. Coates  ...                                                                                                   []
# 82                                  Carrie Dempster  ...                                                                                                   []
# 83                                   Herbert Ainsty  ...                                                                                                   []
# 84                                          Wickham  ...                                                                                                   []
# 85                            little Elise Mitchell  ...                                                                                                   []
# 86                                           Evelyn  ...                                                                                                   []
# 87                                        Cleopatra  ...                                                                                                   []
# 88                                     Mr. Dubonnet  ...                                                                                                   []
# 89                                   Mrs. Parkinson  ...                                                                                                   []
# 90                                            Jenny  ...                                                                                                   []
# 91                                      Mrs. Barnet  ...                                                                                                   []
# 92                                           Milton  ...                                                                                                   []
# 93                                       Nancy Blow  ...                                                                                                   []
# 94                                    the Bradshaws  ...                                                                                                   []
# 95                                     Baron Marbot  ...                                                                                                   []
# 96                                 Marie Antoinette  ...                                                                                                   []
# 97                                           Darwin  ...                                                                                                   []
# 98                                           Beauty  ...                                                                                                   []
# 99                                           Antony  ...                                                                                                   []
# 100                                           Rigby  ...                                                                                                   []
# 101                                  Mrs. Whitbread  ...                                                                                                   []
# 102                                       Armenians  ...                                                                                                   []
# 103                                      Mr. Peters  ...                                                                                                   []
# 104                                    Mrs. Burgess  ...                                                                                                   []
# 105                                  Bartlett pears  ...                                                                                                   []
# 106                                      Miss Alice  ...                                                                                                   []
# 107                                     Lord Gayton  ...                                                                                                   []
# 108                                   Mrs. Foxcroft  ...                                                                                                   []
# 109                                           Lords  ...                                                                                                   []
# 110                                          Wagner  ...                                                                                                   []
# 111                                            Pope  ...                                                                                                   []
# 112                                          Sylvia  ...                                                                                                   []
# 113                                        Mulberry  ...                                                                                                   []
# 114                                   Princess Mary  ...                                                                                                   []
# 115  old King Edward , but was ever so much slimmer  ...                                                                                                   []
# 116                                  Mrs. Bletchley  ...                                                                                                   []
# 117                                           Roses  ...                                                                                                   []
# 118                                  William Morris  ...                                                                                                   []
# 119                                    Ellen Atkins  ...                                                                                                   []
# 120                                         Othello  ...                                                                                                   []
# 121                                          Brahms  ...                                                                                                   []
# 122                                  Messrs. Hooper  ...                                                                                                   []
# 123                                          Huxley  ...                                                                                                   []
# 124                                           Dante  ...                                                                                                   []
# 125                                     The English  ...                                                                                        [(silent, 1)]
# 126                               the Warren Smiths  ...                                                                                                   []
# 127                                         Lowndes  ...                                                                                                   []
# 128                                      Sir Talbot  ...                                                                                                   []
# 129                                         Perkins  ...                                                                                                   []
# 130                                       Albanians  ...                                                                                                   []
# 131                                     the Germans  ...                                                                                      [(villains, 1)]
# 132                       the Rev. Edward Whittaker  ...                                                                                                   []
# 133                            young Charles Morris  ...                                                                                                   []
# 134                                     Miss Elaine  ...                                                                                                   []
# 135                                     Mrs. Morris  ...                                                                                                   []
# 136                                    Miss Lovejoy  ...                                                                                                   []
# 137                                      Ralph Lyon  ...                                                                                                   []
#
# [138 rows x 8 columns]

# %% [markdown]
# # Get Quotation Data

# %%
# Load quotation data
quote_df = pd.read_csv("my_book_dir/my_book.quotes", delimiter='\t')
quote_df['char_id'] = quote_df['char_id'].astype(str)
quote_df = pd.merge(df[['Character ID', 'Name']], quote_df, left_on = 'Character ID', right_on= 'char_id')

# %% [markdown]
# # View Quotation Data

# %% [markdown]
# Let's view the first 100 identified quotations

# %%
quote_df.sort_values(by='quote_start')[:100]
# Out:
#     Character ID  ...                                                                                                quote
# 81           146  ...                                                                    Musing among the vegetables?--was
# 82           146  ...                                                             it?--"I prefer men to cauliflowers"--was
# 239          159  ...                                                                  Good - morning to you , Clarissa !
# 240          159  ...                                                                              Where are you off to ?
# 337          141  ...                                                                          I love walking in London ,
# 338          141  ...                                                   Really it 's better than walking in the country .
# 368          160  ...                                                                                    to see doctors .
# 0            144  ...                                                                                       That is all ,
# 1            144  ...                                                                                       That is all ,
# 185          173  ...                                                                                 I have had enough .
# 360          176  ...                                                                           Dear , those motor cars ,
# 361          180  ...                                                                       The Proime Minister 's kyar .
# 309          182  ...                                                                                           Come on ,
# 310          182  ...                                                                                         All right !
# 297          181  ...                                                                                  I will kill myself
# 311          182  ...                                                                                 Now we will cross ,
# 369          192  ...                                                                                             Glaxo ,
# 372          193  ...                                                                                            Kreemo ,
# 373          193  ...                                                                                      That 's an E ,
# 312          182  ...                                                                            Look , look , Septimus !
# 339          198  ...                                                                                          Septimus !
# 340          198  ...                                                                               What are you saying ?
# 341          198  ...                                                                                              Look ,
# 342          198  ...                                                                                              Look ,
# 343          198  ...                                                                                              Look ,
# 344          198  ...                                                                                              Look ,
# 345          198  ...                                                                                           Oh look ,
# 346          198  ...                                                                        Not this way -- over there !
# 2            144  ...                                                                          What are they looking at ?
# 324          143  ...                                                                               Mr. Dalloway , ma'am--
# 3            144  ...                           Lady Bruton wishes to know if Mr. Dalloway will lunch with her to - day .
# 4            144  ...                               Mr. Dalloway , ma'am , told me to tell you he would be lunching out .
# 5            144  ...                                                                                              Dear !
# 6            144  ...                                                                                      Fear no more ,
# 156          169  ...                                         She is beneath this roof . . . . She is beneath this roof !
# 157          169  ...                                                if it were now to die ' twere now to be most happy .
# 158          169  ...                                                                       What a shame to sit indoors !
# 83           146  ...                                                                                     Star - gazing ?
# 159          169  ...                                                                                    Oh this horror !
# 160          169  ...                                                                                       sentimental ,
# 325          143  ...                                                                                           Oh Lucy ,
# 326          143  ...                                                                         the silver does look nice !
# 327          143  ...                                                                                           And how ,
# 328          143  ...                                                             how did you enjoy the play last night ?
# 329          143  ...                                                                Oh , they had to go before the end !
# 330          143  ...                                                                        They had to be back at ten !
# 331          143  ...                                                                 So they do n't know what happened ,
# 332          143  ...                                                                          That does seem hard luck ,
# 333          143  ...                                                                     That does seem rather a shame ,
# 334          143  ...                          Take it away ! Give it to Mrs. Walker with my compliments ! Take it away !
# 271          163  ...                                                           But , thank you , Lucy , oh , thank you ,
# 7            144  ...                                                                                         that is all
# 272          163  ...                                She will see me . After five years in India , Clarissa will see me .
# 84           146  ...                                                                               Who can -- what can ,
# 8            144  ...                                                                                   And how are you ?
# 85           146  ...                                                               How heavenly it is to see you again !
# 9            144  ...                                                                              And what 's all this ?
# 10           144  ...                                                  Richard 's very well . Richard 's at a Committee ,
# 11           144  ...                                                                        Which I sha n't ask you to ,
# 12           144  ...                                                                                     My dear Peter !
# 13           144  ...                                 But it 's so extraordinary that you should have come this morning !
# 14           144  ...                                                                                   Do you remember ,
# 86           146  ...                                                            how the blinds used to flap at Bourton ?
# 87           146  ...                                                                                          They did ,
# 15           144  ...                                                  I often wish I 'd got on better with your father ,
# 16           144  ...                                                     But he never liked any one who -- our friends ,
# 17           144  ...                                                                                Herbert has it now ,
# 18           144  ...                                                                              I never go there now ,
# 19           144  ...                                                                          Do you remember the lake ?
# 20           144  ...                                                                                              lake .
# 88           146  ...                                                             This is what I have made of it ! This !
# 89           146  ...                                                                                               Yes ,
# 21           144  ...                                                                                   Yes , yes , yes ,
# 90           146  ...                                                                Well , and what 's happened to you ?
# 91           146  ...                                                                                Millions of things !
# 92           146  ...                                                                                      I am in love ,
# 93           146  ...                                                                                           In love ,
# 22           144  ...                                                                      in love with a girl in India .
# 23           144  ...                                                                                           In love !
# 94           146  ...                                                                                    And who is she ?
# 95           146  ...                                                                   A married woman , unfortunately ,
# 96           146  ...                                                            the wife of a Major in the Indian Army .
# 97           146  ...                                                                                           She has ,
# 24           144  ...   two small children ; a boy and a girl ; and I have come over to see my lawyers about the divorc...
# 98           146  ...                                                                      But what are you going to do ?
# 99           146  ...                                                                                           Tell me ,
# 25           144  ...                                                           Are you happy , Clarissa ? Does Richard--
# 231          158  ...                                                                              Here is my Elizabeth ,
# 100          146  ...                                                                                        How d'y do ?
# 101          146  ...                                                                                 Hullo , Elizabeth !
# 26           144  ...                                                                               Good - bye , Clarissa
# 27           144  ...                                                                                     Peter ! Peter !
# 28           144  ...                                                My party to - night ! Remember my party to - night !
# 29           144  ...                                                                      Remember my party to - night !
# 30           144  ...                                                                          Here is my Elizabeth!--that
# 102          146  ...                                                                                               you ,
# 103          146  ...                                                                                            Oh yes .
# 104          146  ...                                                            There is nothing more to - night , sir ?
# 105          146  ...                                                                             The death of the soul .
# 106          146  ...                                                                                       Lord , Lord !
#
# [100 rows x 9 columns]

# %% [markdown]
# # Get Named Entities

# %% [markdown]
# Read in named entities and view all named entities

# %%
entity_df = pd.read_csv("my_book_dir/my_book.entities", delimiter='\t')
entity_df
# Out:
#        COREF  ...                                                              text
# 0        141  ...                                                     Mrs. Dalloway
# 1        141  ...                                                    Virginia Woolf
# 2        142  ...                                            Gutenberg of Australia
# 3        142  ...  Don Lainson dlainson@sympatico.ca Project Gutenberg of Australia
# 4        397  ...                                                                We
# ...      ...  ...                                                               ...
# 11302      0  ...                                                                me
# 11303    144  ...                                                          Clarissa
# 11304    146  ...                                                                he
# 11305    144  ...                                                               she
# 11306    142  ...                                               Gutenberg Australia
#
# [11307 rows x 6 columns]

# %% [markdown]
# Get a breakdown of all the named entitiy categories

# %%
entity_df['cat'].value_counts()
# Out:
# PER    10019
# FAC      705
# GPE      295
# LOC      182
# VEH      100
# ORG        6
# Name: cat, dtype: int64

# %% [markdown]
# # Get Locations

# %% [markdown]
# Let's view the commonly mentioned locations.

# %%
entity_filter = entity_df['cat'] == 'LOC'
entity_df[entity_filter]['text'].value_counts().reset_index().rename(columns={'index':'entity'})
# Out:
#                                            entity  text
# 0                                       the world    47
# 1                                         the sea     9
# 2                                       the earth     8
# 3                                 the whole world     6
# 4                                     the country     5
# 5                                        the lake     4
# 6                                      the desert     4
# 7                                       the river     4
# 8                                      the Strand     3
# 9                                         a river     2
# 10                                       the Park     2
# 11                                 the wilderness     2
# 12                                        a cliff     2
# 13                                 the Serpentine     2
# 14                                  the Himalayas     2
# 15                                      mountains     2
# 16                                      the woods     2
# 17                                   the universe     2
# 18                                          shore     2
# 19                                      The world     2
# 20                                The whole world     2
# 21                                 across country     1
# 22                                   West to East     1
# 23                          the edge of the world     1
# 24                 the fountain in Regent 's Park     1
# 25                                      the Abbey     1
# 26                                      The earth     1
# 27                                   his district     1
# 28                                     Leith Hill     1
# 29                                bleak hillsides     1
# 30                                           lake     1
# 31                                this warm place     1
# 32                        a peak in the Himalayas     1
# 33                                           land     1
# 34                             the state of India     1
# 35                                    the heights     1
# 36                       that territory of theirs     1
# 37                                   the West End     1
# 38                           the coast of Norfolk     1
# 39                  that leaf - encumbered forest     1
# 40                                    a hill- top     1
# 41                those fields down in Devonshire     1
# 42                                         plains     1
# 43                                      some hill     1
# 44                                      the hills     1
# 45                                  nowhere to go     1
# 46                                       the East     1
# 47                                 solitary peaks     1
# 48                             the meadow of life     1
# 49                                             it     1
# 50                                      the beach     1
# 51  a green grass mound on some primeval hillside     1
# 52                                     the places     1
# 53                                     the fields     1
# 54                                      deep seas     1
# 55                            the entire universe     1
# 56                         those tremendous hills     1
# 57                                      the wilds     1
# 58                    the northern part of London     1
# 59                                         rivers     1
# 60                                 stubble fields     1
# 61                                        a world     1
# 62                         the shore of the world     1
# 63                                        a beach     1
# 64                                the forest ride     1
# 65                                  foreign parts     1
# 66                                       a desert     1
# 67                                        the pit     1
# 68                    the mud and swamp of Africa     1
# 69                                    the seaside     1
# 70                                     this world     1
# 71                     this sky above Westminster     1
# 72                               this isle of men     1
# 73                                     the island     1
# 74                       this pocket of still air     1
# 75                                  all the world     1
# 76                 woods made of sky and branches     1
# 77                                       the bank     1
# 78                                            sea     1
# 79                                    a landscape     1
# 80                       wonderful gleaming lakes     1
# 81                            their secure shores     1
# 82                                   a calm ocean     1
# 83                                     the waters     1
# 84                                the river - bed     1
# 85                                 the Suez Canal     1
# 86                              the sea flows now     1
# 87                               the troubled sea     1
# 88                           the fields of Greece     1

# %% [markdown]
# # Get People

# %% [markdown]
# Let's view the commonly mentioned people.

# %%
entity_filter = entity_df['cat'] == 'PER'
entity_df[entity_filter]['text'].value_counts().reset_index().rename(columns={'index':'entity'})[:50]
# Out:
#                entity  text
# 0                 her  1221
# 1                 she  1152
# 2                  he   908
# 3                 his   489
# 4                 him   419
# 5                 She   372
# 6                they   283
# 7                  He   269
# 8            Clarissa   242
# 9                them   161
# 10              their   158
# 11                  I   115
# 12                you    98
# 13                one    96
# 14              Peter    93
# 15               They    89
# 16            himself    89
# 17            Richard    79
# 18              Sally    76
# 19             people    76
# 20        Peter Walsh    71
# 21            herself    70
# 22          Elizabeth    67
# 23           Septimus    65
# 24        Miss Kilman    56
# 25        Lady Bruton    54
# 26               Hugh    53
# 27              Rezia    52
# 28        Sir William    44
# 29                 me    39
# 30         Dr. Holmes    35
# 31              women    31
# 32                 my    29
# 33                 we    28
# 34             Holmes    28
# 35      Mrs. Dalloway    28
# 36               your    26
# 37                Her    25
# 38        Mrs. Filmer    21
# 39   Richard Dalloway    21
# 40              Evans    20
# 41           Dalloway    18
# 42         each other    18
# 43  Clarissa Dalloway    18
# 44     Hugh Whitbread    18
# 45                our    17
# 46                You    17
# 47               Lucy    17
# 48                God    17
# 49                men    17

# %% [markdown]
# # Get Geopolitical Entities

# %% [markdown]
# Let's view the commonly mentioned geopolitical entities.

# %%
entity_filter = entity_df['cat'] == 'GPE'
entity_df[entity_filter]['text'].value_counts().reset_index().rename(columns={'index':'entity'})[:50]
# Out:
#                    entity  text
# 0                  London    43
# 1                 Bourton    25
# 2                   India    25
# 3                 England    16
# 4             Westminster    10
# 5             the country     8
# 6              Manchester     7
# 7                  Surrey     5
# 8               Whitehall     5
# 9              Kensington     5
# 10             Piccadilly     5
# 11                 Oxford     5
# 12                  Burma     5
# 13                Norfolk     4
# 14                  Wales     4
# 15                  there     3
# 16         Constantinople     3
# 17                  Milan     3
# 18                   Eton     3
# 19              Greenwich     3
# 20                   Hull     3
# 21           South Africa     3
# 22                Mayfair     3
# 23                  Italy     3
# 24                Pimlico     3
# 25                 Ealing     2
# 26                 France     2
# 27                  Court     2
# 28                  Paris     2
# 29             Bloomsbury     2
# 30                 Moscow     2
# 31               Brighton     2
# 32               Hatfield     2
# 33              Liverpool     2
# 34                   town     2
# 35                 Canada     2
# 36              Edinburgh     2
# 37               Paradise     2
# 38        the whole place     1
# 39              the state     1
# 40  this dear , dear land     1
# 41             Parliament     1
# 42            Clieveden--     1
# 43            August 1922     1
# 44                 Euston     1
# 45                   Rome     1
# 46                 Greece     1
# 47            a continent     1
# 48               Dalloway     1
# 49                Nigeria     1

# %% [markdown]
# # Get Facilities

# %% [markdown]
# Let's view the commonly mentioned facilities.

# %%
entity_filter = entity_df['cat'] == 'FAC'
entity_df[entity_filter]['text'].value_counts().reset_index().rename(columns={'index':'entity'})[:50]
# Out:
#                            entity  text
# 0                        the room    40
# 1                      the street    24
# 2                            home    18
# 3                        upstairs    15
# 4                  Regent 's Park    14
# 5                           there    10
# 6                     the terrace     9
# 7                     Bond Street     9
# 8                       the house     9
# 9                        the hall     7
# 10                   the pavement     7
# 11                  Harley Street     7
# 12                    her bedroom     7
# 13              Buckingham Palace     6
# 14             the drawing - room     6
# 15                       the Mall     6
# 16                             it     6
# 17                     downstairs     6
# 18                    the streets     5
# 19             the smoking - room     5
# 20                     the Strand     5
# 21                Victoria Street     5
# 22                    the passage     4
# 23                    the kitchen     4
# 24                           here     4
# 25             her drawing - room     4
# 26                       the Park     4
# 27    Regent 's Park Tube station     4
# 28                    the landing     4
# 29                      the rooms     3
# 30                         a room     3
# 31                     the Palace     3
# 32                       the shop     3
# 33              her drawing- room     3
# 34                            its     3
# 35  a large house near Manchester     3
# 36                    St. Paul 's     3
# 37                    Navy Stores     3
# 38                       a garden     3
# 39              the dining - room     3
# 40                      the shops     3
# 41                    the bedroom     3
# 42           the House of Commons     3
# 43                       a church     3
# 44       the Tottenham Court Road     3
# 45                   Brook Street     3
# 46               Trafalgar Square     3
# 47                      his house     3
# 48                      her house     3
# 49                  Oxford Street     3

# %% [markdown]
# ## Get Vehicles

# %% [markdown]
# Let's view the commonly mentioned vehicles.

# %%
entity_filter = entity_df['cat'] == 'VEH'
entity_df[entity_filter]['text'].value_counts().reset_index().rename(columns={'index':'entity'})[:50]
# Out:
#                                entity  text
# 0                             the car     8
# 1                       the motor car     7
# 2                          motor cars     5
# 3                                vans     5
# 4                       the ambulance     4
# 5                          an omnibus     4
# 6                            the boat     4
# 7                       the aeroplane     4
# 8                             a train     3
# 9                             The car     2
# 10                              ships     2
# 11                     the motor cars     2
# 12                     this ambulance     2
# 13                         board ship     2
# 14                        the omnibus     2
# 15                              a bus     2
# 16                           the cabs     2
# 17                        a motor car     2
# 18                           his taxi     1
# 19                     that motor car     1
# 20                 a railway carriage     1
# 21  Sir William Bradshaw 's motor car     1
# 22                               cabs     1
# 23             Every cart or carriage     1
# 24                            the bus     1
# 25                      the taxi cabs     1
# 26                     that aeroplane     1
# 27                      The motor car     1
# 28                          omnibuses     1
# 29                     the dog - cart     1
# 30                          a steamer     1
# 31                             a cart     1
# 32                    Durtnall 's van     1
# 33                       an aeroplane     1
# 34                     two motor cars     1
# 35                              a van     1
# 36                            the cab     1
# 37                    the passing car     1
# 38                 the grey motor car     1
# 39                          motor car     1
# 40                      The aeroplane     1
# 41                           this car     1
# 42                              Buses     1
# 43                    the motor - car     1
# 44                 the midnight train     1
# 45                   a brewer 's cart     1
# 46                   those motor cars     1
# 47                      the carriages     1
# 48                     a sinking ship     1
# 49                       single carts     1
